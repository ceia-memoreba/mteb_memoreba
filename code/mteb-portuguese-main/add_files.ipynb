# %%
import huggingface_hub
from tqdm.auto import tqdm

size_data = {}

for dataset_info in tqdm(huggingface_hub.list_datasets(author="mteb-pt", full=False)):
    try:
        full_data = huggingface_hub.dataset_info(dataset_info.id, revision='refs/convert/parquet', files_metadata=True)
    except:
        full_data = huggingface_hub.dataset_info(dataset_info.id, files_metadata=True)
    total_size = 0
    for s in full_data.siblings:
        total_size += s.size

    #MB total_size / 1024
    #GB total_size / 1024 / 1024
    size_data[dataset_info.id] = total_size
# Out:
# 0it [00:00, ?it/s]

# %%
x = list(size_data.keys())
x.sort(key=lambda x: size_data[x], reverse=False)

# %%
TASK_LIST_CLASSIFICATION = [
    "AmazonCounterfactualClassification",
    "AmazonPolarityClassification",
    "AmazonReviewsClassification",
    "Banking77Classification",
    "EmotionClassification",
    "ImdbClassification",
    "MassiveIntentClassification",
    "MassiveScenarioClassification",
    "MTOPDomainClassification",
    "MTOPIntentClassification",
    "ToxicConversationsClassification",
    "TweetSentimentExtractionClassification",
]

TASK_LIST_CLUSTERING = [
    "ArxivClusteringP2P",
    "ArxivClusteringS2S",
    "BiorxivClusteringP2P",
    "BiorxivClusteringS2S",
    "MedrxivClusteringP2P",
    "MedrxivClusteringS2S",
    "RedditClustering",
    "RedditClusteringP2P",
    "StackExchangeClustering",
    "StackExchangeClusteringP2P",
    "TwentyNewsgroupsClustering",
]

TASK_LIST_PAIR_CLASSIFICATION = [
    "SprintDuplicateQuestions",
    "TwitterSemEval2015",
    "TwitterURLCorpus",
]

TASK_LIST_RERANKING = [
    "AskUbuntuDupQuestions",
    "MindSmallReranking",
    "SciDocsRR",
    "StackOverflowDupQuestions",
]

TASK_LIST_RETRIEVAL = [
    "ArguAna",
    "ClimateFEVER",
    "CQADupstackAndroidRetrieval",
    "CQADupstackEnglishRetrieval",
    "CQADupstackGamingRetrieval",
    "CQADupstackGisRetrieval",
    "CQADupstackMathematicaRetrieval",
    "CQADupstackPhysicsRetrieval",
    "CQADupstackProgrammersRetrieval",
    "CQADupstackStatsRetrieval",
    "CQADupstackTexRetrieval",
    "CQADupstackUnixRetrieval",
    "CQADupstackWebmastersRetrieval",
    "CQADupstackWordpressRetrieval",
    "DBPedia",
    "FEVER",
    "FiQA2018",
    "HotpotQA",
    "MSMARCO",
    "NFCorpus",
    "NQ",
    "QuoraRetrieval",
    "SCIDOCS",
    "SciFact",
    "Touche2020",
    "TRECCOVID",
]

TASK_LIST_STS = [
    "BIOSSES",
    "SICK-R",
    "STS12",
    "STS13",
    "STS14",
    "STS15",
    "STS16",
    "STS17",
    "STS22",
    "STSBenchmark",
    "SummEval",
]

TASK_LIST_RETRIEVAL_LAW = [
    "LegalSummarization",
    "LegalBenchConsumerContractsQA",
    "LegalBenchCorporateLobbying",
    "AILACasedocs",
    "AILAStatutes",
    "LeCaRDv2",
    "LegalQuAD",
    "GerDaLIRSmall",
]

TASK_JINAAI = [
    "BigPatentClustering",
    "WikiCitiesClustering",
    "NarrativeQA"
]

TASKS_LEMB = [
    "LEMBNarrativeQARetrieval",
    "LEMBNeedleRetrieval",
    "LEMBPasskeyRetrieval",
    "LEMBQMSumRetrieval",
    "LEMBSummScreenFDRetrieval",
    "LEMBWikimQARetrieval"
]

TASK_LIST = (
    TASK_LIST_CLASSIFICATION
    + TASK_LIST_CLUSTERING
    + TASK_LIST_PAIR_CLASSIFICATION
    + TASK_LIST_RERANKING
    + TASK_LIST_RETRIEVAL
    + TASK_LIST_STS
    + TASK_LIST_RETRIEVAL_LAW
    + TASK_JINAAI
    + TASKS_LEMB
)

# %%
import mteb

# %%
import inspect
TASKS_TO_CONVERT = {}
class_name_to_task_name = {}
for task in mteb.get_tasks():
    name = task.metadata.name
    class_name = type(task).__name__
    if name in TASK_LIST or class_name in TASK_LIST:
        TASKS_TO_CONVERT[name] = {
            "name": name,
            "class_name": class_name,
            "path": inspect.getfile(task.__class__)
        }
    #class_name_to_task_name[class_name] = name
    #print(name, path)

# %%
TASKS_PT = [
    'BiossesSTS',
    "SickrSTS",
    "STS15STS",
    "STS16STS",
    #"STSBenchmarkMultilingualSTS", # has pt
    "AskUbuntuDupQuestions", #Rerank
    "StackOverflowDupQuestions", #Rerank
    "SprintDuplicateQuestionsPC", # pair cla
    "TwitterSemEval2015PC", #Pair cls
    "SummEvalSummarization", #Summarization
    "TwentyNewsgroupsClustering", #cluste
    "MedrxivClusteringS2S", #clust
    "Banking77Classification",
    #"MassiveIntentClassification", #haspt
    #"MassivScenarioClassification", #haspt
    "SciFactRetrieval",
    "CQADupstackStatsRetrieval",
    #"MultiLongDocRetrieval" # has pt
]

new_map = {}
for task in TASKS_PT:
    if task in class_name_to_task_name:
        if task != class_name_to_task_name[task]:
            new_map['PTTrad'+task] = 'PTTrad'+class_name_to_task_name[task]
new_map
# Out:
# {'PTTradBiossesSTS': 'PTTradBIOSSES',
#  'PTTradSickrSTS': 'PTTradSICK-R',
#  'PTTradSTS15STS': 'PTTradSTS15',
#  'PTTradSTS16STS': 'PTTradSTS16',
#  'PTTradSprintDuplicateQuestionsPC': 'PTTradSprintDuplicateQuestions',
#  'PTTradTwitterSemEval2015PC': 'PTTradTwitterSemEval2015',
#  'PTTradSummEvalSummarization': 'PTTradSummEval'}

# %%
import shutil

basepath = "/mnt/e/ceia/mteb/mteb/mteb/tasks"
for folder in os.listdir(basepath):
    lang_task_folder = os.path.join(basepath, folder, "por_translated")
    if os.path.exists(lang_task_folder):
        shutil.rmtree(lang_task_folder)

# %%
import glob
import os
import shutil

basepath = "/mnt/e/ceia/mteb/mteb/mteb/tasks"
for folder in os.listdir(basepath):
    lang_task_folder = os.path.join(basepath, folder, "por_translated")
    if os.path.exists(lang_task_folder):
        shutil.rmtree(lang_task_folder)

for task_name, data in TASKS_TO_CONVERT.items():
    original_filepath = data["path"]
    class_name = data["class_name"]
    if '/eng/' in original_filepath:
        lang = 'eng'
    elif '/multilingual/' in original_filepath:
        lang = 'multilingual'
    else:
        print(task_name)
        continue
    original_dir = os.path.dirname(original_filepath)
    new_dir = original_dir.replace(f'/{lang}', '/por_translated')
    new_name = "PTT_"+task_name
    new_class_name = "PTT_"+class_name
    new_filepath = os.path.join(new_dir, new_class_name+'.py')
    os.makedirs(new_dir, exist_ok=True)

    print(f'cp {original_filepath} {new_filepath}')
    os.system(f'cp {original_filepath} {new_filepath}')
    with open(new_filepath, 'r') as f:
        doc = f.read()
    
    """
    if task_name != class_name:
        if len(task_name) > len(class_name):
            doc = doc.replace(task_name, new_name)
            doc = doc.replace(class_name, new_class_name)
        else:
            doc = doc.replace(class_name, new_class_name)
            doc = doc.replace(task_name, new_name)
    else:
        doc = doc.replace(task_name, new_name)
    """
    name_prefix = '"'
    name_prefix2 = "'"
    class_prefix = 'class '
    doc = doc.replace(name_prefix+task_name, name_prefix+new_name)
    doc = doc.replace(name_prefix2+task_name, name_prefix2+new_name)
    doc = doc.replace(class_prefix+class_name, class_prefix+new_class_name)
    #doc = doc.replace('\"path\": \"mteb/', '\"path\": \"mteb-pt/')
    if 'por-Latn' not in doc and 'por_Latn' not in doc:
        doc = doc.replace('eng-Latn', 'por-Latn')
        doc = doc.replace('eng_Latn', 'por_Latn')
        doc = doc.replace('\"eng', '\"por')
        doc = doc.replace('eng\"', 'por\"')
        doc = doc.replace('\"en\"', '\"pt\"')
        doc = doc.replace('\"en-', '\"pt-')
        doc = doc.replace('-en\"', '-pt\"')
    lines = doc.split('\n')
    for i, line in enumerate(lines):
        if '"revision": "' in line:
            lines[i] = " "*line.index('"') + '\"revision\": \"main\",'
        if '"path": "' in line:
            if "mteb/" in line:
                lines[i] = lines[i].replace("mteb/", "pt-mteb/translated_")
            else:
                s1 = line.split(':')
                if '/' in s1[-1]:
                    s2 = s1[-1].split('/')[-1]
                else:
                    s2 = s1[-1][s1[-1].find('"')+1:]
                path = ' "pt-mteb/translated_' + s2
                lines[i] = s1[0] + ':' + path

    with open(new_filepath, 'w') as f:
        f.write('\n'.join(lines))

    init_filepath = os.path.join(os.path.dirname(original_dir), '__init__.py')
    with open(init_filepath, 'r') as f:
        doc = f.read()
    import_line = f'from .por_translated.{new_class_name} import *'
    if import_line not in doc:
        doc = doc.strip()
        doc += '\n' + import_line + '\n'
        with open(init_filepath, 'w') as f:
            f.write(doc)
# Out:
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/AmazonPolarityClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_AmazonPolarityClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/Banking77Classification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_Banking77Classification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/EmotionClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_EmotionClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/ImdbClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_ImdbClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/ToxicConversationsClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_ToxicConversationsClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/eng/TweetSentimentExtractionClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_TweetSentimentExtractionClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/AmazonCounterfactualClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_AmazonCounterfactualClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/AmazonReviewsClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_AmazonReviewsClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/MassiveIntentClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_MassiveIntentClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/MassiveScenarioClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_MassiveScenarioClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/MTOPDomainClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_MTOPDomainClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/multilingual/MTOPIntentClassification.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Classification/por_translated/PTT_MTOPIntentClassification.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/ArxivClusteringS2S.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_ArxivClusteringS2S.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/BigPatentClustering.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_BigPatentClustering.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/BiorxivClusteringP2P.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_BiorxivClusteringP2P.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/BiorxivClusteringS2S.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_BiorxivClusteringS2S.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/MedrxivClusteringP2P.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_MedrxivClusteringP2P.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/MedrxivClusteringS2S.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_MedrxivClusteringS2S.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/RedditClustering.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_RedditClustering.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/RedditClusteringP2P.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_RedditClusteringP2P.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/StackExchangeClustering.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_StackExchangeClustering.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/StackExchangeClusteringP2P.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_StackExchangeClusteringP2P.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/TwentyNewsgroupsClustering.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_TwentyNewsgroupsClustering.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/eng/WikiCitiesClustering.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Clustering/por_translated/PTT_WikiCitiesClustering.py
# GerDaLIRSmall
# LegalQuAD
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/AILACasedocsRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_AILACasedocs.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/AILAStatutesRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_AILAStatutes.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/ArguAnaRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_ArguAna.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/ClimateFEVERRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_ClimateFEVER.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackAndroidRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackAndroidRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackEnglishRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackEnglishRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackGamingRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackGamingRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackGisRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackGisRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackMathematicaRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackMathematicaRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackPhysicsRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackPhysicsRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackProgrammersRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackProgrammersRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackStatsRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackStatsRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackTexRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackTexRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackUnixRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackUnixRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackWebmastersRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackWebmastersRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/CQADupstackWordpressRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_CQADupstackWordpressRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/DBPediaRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_DBPedia.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/FEVERRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_FEVER.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/FiQA2018Retrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_FiQA2018.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/HotpotQARetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_HotpotQA.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LegalBenchConsumerContractsQARetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LegalBenchConsumerContractsQA.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LegalBenchCorporateLobbyingRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LegalBenchCorporateLobbying.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LegalSummarizationRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LegalSummarization.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBNarrativeQARetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBNarrativeQARetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBNeedleRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBNeedleRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBPasskeyRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBPasskeyRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBQMSumRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBQMSumRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBSummScreenFDRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBSummScreenFDRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/LEMBWikimQARetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_LEMBWikimQARetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/MSMARCORetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_MSMARCO.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/NFCorpusRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_NFCorpus.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/NQRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_NQ.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/QuoraRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_QuoraRetrieval.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/SCIDOCSRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_SCIDOCS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/SciFactRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_SciFact.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/Touche2020Retrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_Touche2020.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/eng/TRECCOVIDRetrieval.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Retrieval/por_translated/PTT_TRECCOVID.py
# LeCaRDv2
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/eng/SprintDuplicateQuestionsPC.py /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/por_translated/PTT_SprintDuplicateQuestionsPC.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/eng/TwitterSemEval2015PC.py /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/por_translated/PTT_TwitterSemEval2015PC.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/eng/TwitterURLCorpusPC.py /mnt/e/ceia/mteb/mteb/mteb/tasks/PairClassification/por_translated/PTT_TwitterURLCorpusPC.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/eng/AskUbuntuDupQuestions.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/por_translated/PTT_AskUbuntuDupQuestions.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/eng/MindSmallReranking.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/por_translated/PTT_MindSmallReranking.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/eng/SciDocsReranking.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/por_translated/PTT_SciDocsReranking.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/eng/StackOverflowDupQuestions.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Reranking/por_translated/PTT_StackOverflowDupQuestions.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/BiossesSTS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_BiossesSTS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/SickrSTS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_SickrSTS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STS12STS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS12STS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STS13STS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS13STS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STS14STS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS14STS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STS15STS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS15STS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STS16STS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS16STS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/eng/STSBenchmarkSTS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STSBenchmarkSTS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/multilingual/STS17CrosslingualSTS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS17Crosslingual.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/multilingual/STS22CrosslingualSTS.py /mnt/e/ceia/mteb/mteb/mteb/tasks/STS/por_translated/PTT_STS22CrosslingualSTS.py
# cp /mnt/e/ceia/mteb/mteb/mteb/tasks/Summarization/eng/SummEvalSummarization.py /mnt/e/ceia/mteb/mteb/mteb/tasks/Summarization/por_translated/PTT_SummEvalSummarization.py

# %%
new_filepath
# Out:
# 'mteb/tasks/STS/eng/PTTradSickrSTS.py'

# %%
task_files
# Out:
# {'BibleNLPBitextMining': 'mteb/tasks/BitextMining/multilingual/BibleNLPBitextMining.py',
#  'BUCCBitextMining': 'mteb/tasks/BitextMining/multilingual/BUCCBitextMining.py',
#  'DiaBLaBitextMining': 'mteb/tasks/BitextMining/multilingual/DiaBLaBitextMining.py',
#  'FloresBitextMining': 'mteb/tasks/BitextMining/multilingual/FloresBitextMining.py',
#  'IN22ConvBitextMining': 'mteb/tasks/BitextMining/multilingual/IN22ConvBitextMining.py',
#  'IN22GenBitextMining': 'mteb/tasks/BitextMining/multilingual/IN22GenBitextMining.py',
#  'NorwegianCourtsBitextMining': 'mteb/tasks/BitextMining/multilingual/NorwegianCourtsBitextMining.py',
#  'norwegian_courts_bitext_mining': 'mteb/tasks/BitextMining/multilingual/norwegian_courts_bitext_mining.py',
#  'NTREXBitextMining': 'mteb/tasks/BitextMining/multilingual/NTREXBitextMining.py',
#  'RomaTalesBitextMining': 'mteb/tasks/BitextMining/multilingual/RomaTalesBitextMining.py',
#  'TatoebaBitextMining': 'mteb/tasks/BitextMining/multilingual/TatoebaBitextMining.py',
#  'AmazonCounterfactualClassification': 'mteb/tasks/Classification/multilingual/AmazonCounterfactualClassification.py',
#  'AmazonReviewsClassification': 'mteb/tasks/Classification/multilingual/AmazonReviewsClassification.py',
#  'IndicLangClassification': 'mteb/tasks/Classification/multilingual/IndicLangClassification.py',
#  'IndicSentimentClassification': 'mteb/tasks/Classification/multilingual/IndicSentimentClassification.py',
#  'MasakhaNEWSClassification': 'mteb/tasks/Classification/multilingual/MasakhaNEWSClassification.py',
#  'MassiveIntentClassification': 'mteb/tasks/Classification/multilingual/MassiveIntentClassification.py',
#  'MassiveScenarioClassification': 'mteb/tasks/Classification/multilingual/MassiveScenarioClassification.py',
#  'MTOPDomainClassification': 'mteb/tasks/Classification/multilingual/MTOPDomainClassification.py',
#  'MTOPIntentClassification': 'mteb/tasks/Classification/multilingual/MTOPIntentClassification.py',
#  'MultiHateClassification': 'mteb/tasks/Classification/multilingual/MultiHateClassification.py',
#  'NordicLangClassification': 'mteb/tasks/Classification/multilingual/NordicLangClassification.py',
#  'ScalaClassification': 'mteb/tasks/Classification/multilingual/ScalaClassification.py',
#  'SouthAfricanLangClassification': 'mteb/tasks/Classification/multilingual/SouthAfricanLangClassification.py',
#  'IndicReviewsClusteringP2P': 'mteb/tasks/Clustering/multilingual/IndicReviewsClusteringP2P.py',
#  'MasakhaNEWSClusteringP2P': 'mteb/tasks/Clustering/multilingual/MasakhaNEWSClusteringP2P.py',
#  'MasakhaNEWSClusteringS2S': 'mteb/tasks/Clustering/multilingual/MasakhaNEWSClusteringS2S.py',
#  'MLSUMClusteringP2P': 'mteb/tasks/Clustering/multilingual/MLSUMClusteringP2P.py',
#  'MLSUMClusteringS2S': 'mteb/tasks/Clustering/multilingual/MLSUMClusteringS2S.py',
#  'WikiClusteringP2P': 'mteb/tasks/Clustering/multilingual/WikiClusteringP2P.py',
#  'OpusparcusPC': 'mteb/tasks/PairClassification/multilingual/OpusparcusPC.py',
#  'PawsX': 'mteb/tasks/PairClassification/multilingual/PawsX.py',
#  'MIRACLReranking': 'mteb/tasks/Reranking/multilingual/MIRACLReranking.py',
#  'IndicQARetrieval': 'mteb/tasks/Retrieval/multilingual/IndicQARetrieval.py',
#  'MintakaRetrieval': 'mteb/tasks/Retrieval/multilingual/MintakaRetrieval.py',
#  'MIRACLRetrieval': 'mteb/tasks/Retrieval/multilingual/MIRACLRetrieval.py',
#  'MultiLongDocRetrieval': 'mteb/tasks/Retrieval/multilingual/MultiLongDocRetrieval.py',
#  'NeuCLIR2022Retrieval': 'mteb/tasks/Retrieval/multilingual/NeuCLIR2022Retrieval.py',
#  'NeuCLIR2023Retrieval': 'mteb/tasks/Retrieval/multilingual/NeuCLIR2023Retrieval.py',
#  'XMarketRetrieval': 'mteb/tasks/Retrieval/multilingual/XMarketRetrieval.py',
#  'XPQARetrieval': 'mteb/tasks/Retrieval/multilingual/XPQARetrieval.py',
#  'XQuADRetrieval': 'mteb/tasks/Retrieval/multilingual/XQuADRetrieval.py',
#  'IndicCrosslingualSTS': 'mteb/tasks/STS/multilingual/IndicCrosslingualSTS.py',
#  'STS17CrosslingualSTS': 'mteb/tasks/STS/multilingual/STS17CrosslingualSTS.py',
#  'STS22CrosslingualSTS': 'mteb/tasks/STS/multilingual/STS22CrosslingualSTS.py',
#  'STSBenchmarkMultilingualSTS': 'mteb/tasks/STS/multilingual/STSBenchmarkMultilingualSTS.py'}

# %%
task_files
# Out:
# {'__init__': 'mteb/tasks/Summarization/fra/__init__.py',
#  'BornholmskBitextMining': 'mteb/tasks/BitextMining/dan/BornholmskBitextMining.py',
#  'BibleNLPBitextMining': 'mteb/tasks/BitextMining/multilingual/BibleNLPBitextMining.py',
#  'BUCCBitextMining': 'mteb/tasks/BitextMining/multilingual/BUCCBitextMining.py',
#  'DiaBLaBitextMining': 'mteb/tasks/BitextMining/multilingual/DiaBLaBitextMining.py',
#  'FloresBitextMining': 'mteb/tasks/BitextMining/multilingual/FloresBitextMining.py',
#  'IN22ConvBitextMining': 'mteb/tasks/BitextMining/multilingual/IN22ConvBitextMining.py',
#  'IN22GenBitextMining': 'mteb/tasks/BitextMining/multilingual/IN22GenBitextMining.py',
#  'NorwegianCourtsBitextMining': 'mteb/tasks/BitextMining/multilingual/NorwegianCourtsBitextMining.py',
#  'norwegian_courts_bitext_mining': 'mteb/tasks/BitextMining/multilingual/norwegian_courts_bitext_mining.py',
#  'NTREXBitextMining': 'mteb/tasks/BitextMining/multilingual/NTREXBitextMining.py',
#  'RomaTalesBitextMining': 'mteb/tasks/BitextMining/multilingual/RomaTalesBitextMining.py',
#  'TatoebaBitextMining': 'mteb/tasks/BitextMining/multilingual/TatoebaBitextMining.py',
#  'SRNCorpusBitextMining': 'mteb/tasks/BitextMining/srn/SRNCorpusBitextMining.py',
#  'VieMedEVBitextMining': 'mteb/tasks/BitextMining/vie/VieMedEVBitextMining.py',
#  'AJGT': 'mteb/tasks/Classification/ara/AJGT.py',
#  'HotelReviewSentimentClassification': 'mteb/tasks/Classification/ara/HotelReviewSentimentClassification.py',
#  'RestaurantReviewSentimentClassification': 'mteb/tasks/Classification/ara/RestaurantReviewSentimentClassification.py',
#  'TweetEmotionClassification': 'mteb/tasks/Classification/ara/TweetEmotionClassification.py',
#  'TweetSarcasmClassification': 'mteb/tasks/Classification/ara/TweetSarcasmClassification.py',
#  'BambaraSentimentClassification': 'mteb/tasks/Classification/bam/BambaraSentimentClassification.py',
#  'BengaliHateSpeechClassification': 'mteb/tasks/Classification/ben/BengaliHateSpeechClassification.py',
#  'BengaliSentimentAnalysis': 'mteb/tasks/Classification/ben/BengaliSentimentAnalysis.py',
#  'BulgarianSentimentClassification': 'mteb/tasks/Classification/bul/BulgarianSentimentClassification.py',
#  'BulgarianStoreReviewSentimentClassfication': 'mteb/tasks/Classification/bul/BulgarianStoreReviewSentimentClassfication.py',
#  'CzechSubjectivityClassification': 'mteb/tasks/Classification/ces/CzechSubjectivityClassification.py',
#  'AngryTweetsClassification': 'mteb/tasks/Classification/dan/AngryTweetsClassification.py',
#  'DanishPoliticalCommentsClassification': 'mteb/tasks/Classification/dan/DanishPoliticalCommentsClassification.py',
#  'DdiscoCohesionClassification': 'mteb/tasks/Classification/dan/DdiscoCohesionClassification.py',
#  'DKHateClassification': 'mteb/tasks/Classification/dan/DKHateClassification.py',
#  'LccSentimentClassification': 'mteb/tasks/Classification/dan/LccSentimentClassification.py',
#  'GreekLegalCodeClassification': 'mteb/tasks/Classification/ell/GreekLegalCodeClassification.py',
#  'GreekSentimentClassification': 'mteb/tasks/Classification/ell/GreekSentimentClassification.py',
#  'AmazonPolarityClassification': 'mteb/tasks/Classification/eng/AmazonPolarityClassification.py',
#  'ArxivClassification': 'mteb/tasks/Classification/eng/ArxivClassification.py',
#  'Banking77Classification': 'mteb/tasks/Classification/eng/Banking77Classification.py',
#  'CanadaTaxCourtOutcomesLegalBenchClassification': 'mteb/tasks/Classification/eng/CanadaTaxCourtOutcomesLegalBenchClassification.py',
#  'ContractNLIConfidentialityOfAgreementLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIConfidentialityOfAgreementLegalBenchClassification.py',
#  'ContractNLIExplicitIdentificationLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIExplicitIdentificationLegalBenchClassification.py',
#  'ContractNLIInclusionOfVerballyConveyedInformationLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIInclusionOfVerballyConveyedInformationLegalBenchClassification.py',
#  'ContractNLILimitedUseLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLILimitedUseLegalBenchClassification.py',
#  'ContractNLINoLicensingLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLINoLicensingLegalBenchClassification.py',
#  'ContractNLINoticeOnCompelledDisclosureLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLINoticeOnCompelledDisclosureLegalBenchClassification.py',
#  'ContractNLIPermissibleAcquirementOfSimilarInformationLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIPermissibleAcquirementOfSimilarInformationLegalBenchClassification.py',
#  'ContractNLIPermissibleCopyLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIPermissibleCopyLegalBenchClassification.py',
#  'ContractNLIPermissibleDevelopmentOfSimilarInformationLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIPermissibleDevelopmentOfSimilarInformationLegalBenchClassification.py',
#  'ContractNLIPermissiblePostAgreementPossessionLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIPermissiblePostAgreementPossessionLegalBenchClassification.py',
#  'ContractNLIReturnOfConfidentialInformationLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLIReturnOfConfidentialInformationLegalBenchClassification.py',
#  'ContractNLISharingWithEmployeesLegalBenchClassification': 'mteb/tasks/Classification/eng/ContractNLISharingWithEmployeesLegalBenchClassification.py',
#  'DBpediaClassification': 'mteb/tasks/Classification/eng/DBpediaClassification.py',
#  'EmotionClassification': 'mteb/tasks/Classification/eng/EmotionClassification.py',
#  'FinancialPhrasebankClassification': 'mteb/tasks/Classification/eng/FinancialPhrasebankClassification.py',
#  'ImdbClassification': 'mteb/tasks/Classification/eng/ImdbClassification.py',
#  'NewsClassification': 'mteb/tasks/Classification/eng/NewsClassification.py',
#  'PatentClassification': 'mteb/tasks/Classification/eng/PatentClassification.py',
#  'ToxicChatClassification': 'mteb/tasks/Classification/eng/ToxicChatClassification.py',
#  'ToxicConversationsClassification': 'mteb/tasks/Classification/eng/ToxicConversationsClassification.py',
#  'TweetSentimentExtractionClassification': 'mteb/tasks/Classification/eng/TweetSentimentExtractionClassification.py',
#  'YelpReviewFullClassification': 'mteb/tasks/Classification/eng/YelpReviewFullClassification.py',
#  'estonian_valence': 'mteb/tasks/Classification/est/estonian_valence.py',
#  'PersianFoodSentimentClassification': 'mteb/tasks/Classification/fas/PersianFoodSentimentClassification.py',
#  'FilipinoHateSpeechClassification': 'mteb/tasks/Classification/fil/FilipinoHateSpeechClassification.py',
#  'FinToxicityClassification': 'mteb/tasks/Classification/fin/FinToxicityClassification.py',
#  'MovieReviewSentimentClassification': 'mteb/tasks/Classification/fra/MovieReviewSentimentClassification.py',
#  'GujaratiNewsClassification': 'mteb/tasks/Classification/guj/GujaratiNewsClassification.py',
#  'HindiDiscourseClassification': 'mteb/tasks/Classification/hin/HindiDiscourseClassification.py',
#  'SentimentAnalysisHindi': 'mteb/tasks/Classification/hin/SentimentAnalysisHindi.py',
#  'CroatianSentimentClassification': 'mteb/tasks/Classification/hrv/CroatianSentimentClassification.py',
#  'IndonesianIdClickbaitClassification': 'mteb/tasks/Classification/ind/IndonesianIdClickbaitClassification.py',
#  'ItalianLinguistAcceptabilityClassification': 'mteb/tasks/Classification/ita/ItalianLinguistAcceptabilityClassification.py',
#  'WRIMEClassification': 'mteb/tasks/Classification/jpn/WRIMEClassification.py',
#  'KannadaNewsClassification': 'mteb/tasks/Classification/kan/KannadaNewsClassification.py',
#  'GeorgianSentimentClassification': 'mteb/tasks/Classification/kat/GeorgianSentimentClassification.py',
#  'KurdishSentimentClassification': 'mteb/tasks/Classification/kur/KurdishSentimentClassification.py',
#  'MalayalamNewsClassification': 'mteb/tasks/Classification/mal/MalayalamNewsClassification.py',
#  'MacedonianTweetSentimentClassification': 'mteb/tasks/Classification/mkd/MacedonianTweetSentimentClassification.py',
#  'MalteseSentimentClassification': 'mteb/tasks/Classification/mlt/MalteseSentimentClassification.py',
#  'AmazonCounterfactualClassification': 'mteb/tasks/Classification/multilingual/AmazonCounterfactualClassification.py',
#  'AmazonReviewsClassification': 'mteb/tasks/Classification/multilingual/AmazonReviewsClassification.py',
#  'IndicLangClassification': 'mteb/tasks/Classification/multilingual/IndicLangClassification.py',
#  'IndicSentimentClassification': 'mteb/tasks/Classification/multilingual/IndicSentimentClassification.py',
#  'MasakhaNEWSClassification': 'mteb/tasks/Classification/multilingual/MasakhaNEWSClassification.py',
#  'MassiveIntentClassification': 'mteb/tasks/Classification/multilingual/MassiveIntentClassification.py',
#  'MassiveScenarioClassification': 'mteb/tasks/Classification/multilingual/MassiveScenarioClassification.py',
#  'MTOPDomainClassification': 'mteb/tasks/Classification/multilingual/MTOPDomainClassification.py',
#  'MTOPIntentClassification': 'mteb/tasks/Classification/multilingual/MTOPIntentClassification.py',
#  'MultiHateClassification': 'mteb/tasks/Classification/multilingual/MultiHateClassification.py',
#  'NordicLangClassification': 'mteb/tasks/Classification/multilingual/NordicLangClassification.py',
#  'ScalaClassification': 'mteb/tasks/Classification/multilingual/ScalaClassification.py',
#  'SouthAfricanLangClassification': 'mteb/tasks/Classification/multilingual/SouthAfricanLangClassification.py',
#  'NepaliNewsClassification': 'mteb/tasks/Classification/nep/NepaliNewsClassification.py',
#  'DutchBookReviewSentimentClassification': 'mteb/tasks/Classification/nld/DutchBookReviewSentimentClassification.py',
#  'NoRecClassification': 'mteb/tasks/Classification/nob/NoRecClassification.py',
#  'NorwegianParliamentClassification': 'mteb/tasks/Classification/nob/NorwegianParliamentClassification.py',
#  'OdiaNewsClassification': 'mteb/tasks/Classification/ory/OdiaNewsClassification.py',
#  'PunjabiNewsClassification': 'mteb/tasks/Classification/pan/PunjabiNewsClassification.py',
#  'PolishClassification': 'mteb/tasks/Classification/pol/PolishClassification.py',
#  'RomanianSentimentClassification': 'mteb/tasks/Classification/ron/RomanianSentimentClassification.py',
#  'SanskritShlokasClassification': 'mteb/tasks/Classification/san/SanskritShlokasClassification.py',
#  'SinhalaNewsClassification': 'mteb/tasks/Classification/sin/SinhalaNewsClassification.py',
#  'SinhalaNewsSourceClassification': 'mteb/tasks/Classification/sin/SinhalaNewsSourceClassification.py',
#  'SlovakSentimentClassification': 'mteb/tasks/Classification/slk/SlovakSentimentClassification.py',
#  'FrenkSlClassification': 'mteb/tasks/Classification/slv/FrenkSlClassification.py',
#  'SiswatiNewsClassification': 'mteb/tasks/Classification/ssw/SiswatiNewsClassification.py',
#  'DalajClassification': 'mteb/tasks/Classification/swe/DalajClassification.py',
#  'SweRecClassification': 'mteb/tasks/Classification/swe/SweRecClassification.py',
#  'TamilNewsClassification': 'mteb/tasks/Classification/tam/TamilNewsClassification.py',
#  'TeluguAndhraJyotiNewsClassification': 'mteb/tasks/Classification/tel/TeluguAndhraJyotiNewsClassification.py',
#  'wisesight_sentiment_classification': 'mteb/tasks/Classification/tha/wisesight_sentiment_classification.py',
#  'TurkishMovieSentimentClassification': 'mteb/tasks/Classification/tur/TurkishMovieSentimentClassification.py',
#  'TurkishProductSentimentClassification': 'mteb/tasks/Classification/tur/TurkishProductSentimentClassification.py',
#  'UyghurSentimentClassification': 'mteb/tasks/Classification/uig/UyghurSentimentClassification.py',
#  'UkrFormalityClassification': 'mteb/tasks/Classification/ukr/UkrFormalityClassification.py',
#  'UrduRomanSentimentClassification': 'mteb/tasks/Classification/urd/UrduRomanSentimentClassification.py',
#  'VieStudentFeedbackClassification': 'mteb/tasks/Classification/vie/VieStudentFeedbackClassification.py',
#  'CMTEBClassification': 'mteb/tasks/Classification/zho/CMTEBClassification.py',
#  'YueOpenriceReviewClassification': 'mteb/tasks/Classification/zho/YueOpenriceReviewClassification.py',
#  'IsiZuluNewsClassification': 'mteb/tasks/Classification/zul/IsiZuluNewsClassification.py',
#  'BlurbsClusteringP2P': 'mteb/tasks/Clustering/deu/BlurbsClusteringP2P.py',
#  'BlurbsClusteringP2PFast': 'mteb/tasks/Clustering/deu/BlurbsClusteringP2PFast.py',
#  'BlurbsClusteringS2S': 'mteb/tasks/Clustering/deu/BlurbsClusteringS2S.py',
#  'BlurbsClusteringS2SFast': 'mteb/tasks/Clustering/deu/BlurbsClusteringS2SFast.py',
#  'TenKGnadClusteringP2P': 'mteb/tasks/Clustering/deu/TenKGnadClusteringP2P.py',
#  'TenKGnadClusteringP2PFast': 'mteb/tasks/Clustering/deu/TenKGnadClusteringP2PFast.py',
#  'TenKGnadClusteringS2S': 'mteb/tasks/Clustering/deu/TenKGnadClusteringS2S.py',
#  'TenKGnadClusteringS2SFast': 'mteb/tasks/Clustering/deu/TenKGnadClusteringS2SFast.py',
#  'ArxivClusteringP2P': 'mteb/tasks/Clustering/eng/ArxivClusteringP2P.py',
#  'ArxivClusteringP2PFast': 'mteb/tasks/Clustering/eng/ArxivClusteringP2PFast.py',
#  'ArxivClusteringS2S': 'mteb/tasks/Clustering/eng/ArxivClusteringS2S.py',
#  'BigPatentClustering': 'mteb/tasks/Clustering/eng/BigPatentClustering.py',
#  'BiorxivClusteringP2P': 'mteb/tasks/Clustering/eng/BiorxivClusteringP2P.py',
#  'BiorxivClusteringS2S': 'mteb/tasks/Clustering/eng/BiorxivClusteringS2S.py',
#  'MedrxivClusteringP2P': 'mteb/tasks/Clustering/eng/MedrxivClusteringP2P.py',
#  'MedrxivClusteringS2S': 'mteb/tasks/Clustering/eng/MedrxivClusteringS2S.py',
#  'RedditClustering': 'mteb/tasks/Clustering/eng/RedditClustering.py',
#  'RedditClusteringP2P': 'mteb/tasks/Clustering/eng/RedditClusteringP2P.py',
#  'StackExchangeClustering': 'mteb/tasks/Clustering/eng/StackExchangeClustering.py',
#  'StackExchangeClusteringP2P': 'mteb/tasks/Clustering/eng/StackExchangeClusteringP2P.py',
#  'TwentyNewsgroupsClustering': 'mteb/tasks/Clustering/eng/TwentyNewsgroupsClustering.py',
#  'WikiCitiesClustering': 'mteb/tasks/Clustering/eng/WikiCitiesClustering.py',
#  'AlloProfClusteringP2P': 'mteb/tasks/Clustering/fra/AlloProfClusteringP2P.py',
#  'AlloProfClusteringS2S': 'mteb/tasks/Clustering/fra/AlloProfClusteringS2S.py',
#  'HALClusteringS2S': 'mteb/tasks/Clustering/fra/HALClusteringS2S.py',
#  'IndicReviewsClusteringP2P': 'mteb/tasks/Clustering/multilingual/IndicReviewsClusteringP2P.py',
#  'MasakhaNEWSClusteringP2P': 'mteb/tasks/Clustering/multilingual/MasakhaNEWSClusteringP2P.py',
#  'MasakhaNEWSClusteringS2S': 'mteb/tasks/Clustering/multilingual/MasakhaNEWSClusteringS2S.py',
#  'MLSUMClusteringP2P': 'mteb/tasks/Clustering/multilingual/MLSUMClusteringP2P.py',
#  'MLSUMClusteringS2S': 'mteb/tasks/Clustering/multilingual/MLSUMClusteringS2S.py',
#  'WikiClusteringP2P': 'mteb/tasks/Clustering/multilingual/WikiClusteringP2P.py',
#  'snl_clustering': 'mteb/tasks/Clustering/nob/snl_clustering.py',
#  'vg_clustering': 'mteb/tasks/Clustering/nob/vg_clustering.py',
#  'PolishClustering': 'mteb/tasks/Clustering/pol/PolishClustering.py',
#  'RomaniBibleClustering': 'mteb/tasks/Clustering/rom/RomaniBibleClustering.py',
#  'FloresClusteringS2S': 'mteb/tasks/Clustering/spa/FloresClusteringS2S.py',
#  'SpanishNewsClusteringP2P': 'mteb/tasks/Clustering/spa/SpanishNewsClusteringP2P.py',
#  'SwednClustering': 'mteb/tasks/Clustering/swe/SwednClustering.py',
#  'swedn_clustering': 'mteb/tasks/Clustering/swe/swedn_clustering.py',
#  'CMTEBClustering': 'mteb/tasks/Clustering/zho/CMTEBClustering.py',
#  'Core17InstructionRetrieval': 'mteb/tasks/InstructionRetrieval/eng/Core17InstructionRetrieval.py',
#  'News21InstructionRetrieval': 'mteb/tasks/InstructionRetrieval/eng/News21InstructionRetrieval.py',
#  'Robust04InstructionRetrieval': 'mteb/tasks/InstructionRetrieval/eng/Robust04InstructionRetrieval.py',
#  'FalseFriendsDeEnPC': 'mteb/tasks/PairClassification/deu/FalseFriendsDeEnPC.py',
#  'CitationPredictionLegalBenchPC': 'mteb/tasks/PairClassification/eng/CitationPredictionLegalBenchPC.py',
#  'ConsumerContractsQALegalBenchPC': 'mteb/tasks/PairClassification/eng/ConsumerContractsQALegalBenchPC.py',
#  'SprintDuplicateQuestionsPC': 'mteb/tasks/PairClassification/eng/SprintDuplicateQuestionsPC.py',
#  'TwitterSemEval2015PC': 'mteb/tasks/PairClassification/eng/TwitterSemEval2015PC.py',
#  'TwitterURLCorpusPC': 'mteb/tasks/PairClassification/eng/TwitterURLCorpusPC.py',
#  'ArmenianParaphrasePC': 'mteb/tasks/PairClassification/hye/ArmenianParaphrasePC.py',
#  'OpusparcusPC': 'mteb/tasks/PairClassification/multilingual/OpusparcusPC.py',
#  'PawsX': 'mteb/tasks/PairClassification/multilingual/PawsX.py',
#  'PolishPC': 'mteb/tasks/PairClassification/pol/PolishPC.py',
#  'CMTEBPairClassification': 'mteb/tasks/PairClassification/zho/CMTEBPairClassification.py',
#  'AskUbuntuDupQuestions': 'mteb/tasks/Reranking/eng/AskUbuntuDupQuestions.py',
#  'MindSmallReranking': 'mteb/tasks/Reranking/eng/MindSmallReranking.py',
#  'SciDocsReranking': 'mteb/tasks/Reranking/eng/SciDocsReranking.py',
#  'StackOverflowDupQuestions': 'mteb/tasks/Reranking/eng/StackOverflowDupQuestions.py',
#  'AlloprofReranking': 'mteb/tasks/Reranking/fra/AlloprofReranking.py',
#  'SyntecReranking': 'mteb/tasks/Reranking/fra/SyntecReranking.py',
#  'MIRACLReranking': 'mteb/tasks/Reranking/multilingual/MIRACLReranking.py',
#  'CMTEBReranking': 'mteb/tasks/Reranking/zho/CMTEBReranking.py',
#  'CodeSearchNetRetrieval': 'mteb/tasks/Retrieval/code/CodeSearchNetRetrieval.py',
#  'dan_fever': 'mteb/tasks/Retrieval/dan/dan_fever.py',
#  't2nord_retrieval': 'mteb/tasks/Retrieval/dan/t2nord_retrieval.py',
#  'twitterhjerne': 'mteb/tasks/Retrieval/dan/twitterhjerne.py',
#  'GerDaLIRRetrieval': 'mteb/tasks/Retrieval/deu/GerDaLIRRetrieval.py',
#  'GerDaLIRSmallRetrieval': 'mteb/tasks/Retrieval/deu/GerDaLIRSmallRetrieval.py',
#  'GermanDPRRetrieval': 'mteb/tasks/Retrieval/deu/GermanDPRRetrieval.py',
#  'GermanQuADRetrieval': 'mteb/tasks/Retrieval/deu/GermanQuADRetrieval.py',
#  'LegalQuADRetrieval': 'mteb/tasks/Retrieval/deu/LegalQuADRetrieval.py',
#  'GreekCivicsQA': 'mteb/tasks/Retrieval/ell/GreekCivicsQA.py',
#  'AILACasedocsRetrieval': 'mteb/tasks/Retrieval/eng/AILACasedocsRetrieval.py',
#  'AILAStatutesRetrieval': 'mteb/tasks/Retrieval/eng/AILAStatutesRetrieval.py',
#  'ArguAnaRetrieval': 'mteb/tasks/Retrieval/eng/ArguAnaRetrieval.py',
#  'ClimateFEVERRetrieval': 'mteb/tasks/Retrieval/eng/ClimateFEVERRetrieval.py',
#  'CQADupstackAndroidRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackAndroidRetrieval.py',
#  'CQADupstackEnglishRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackEnglishRetrieval.py',
#  'CQADupstackGamingRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackGamingRetrieval.py',
#  'CQADupstackGisRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackGisRetrieval.py',
#  'CQADupstackMathematicaRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackMathematicaRetrieval.py',
#  'CQADupstackPhysicsRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackPhysicsRetrieval.py',
#  'CQADupstackProgrammersRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackProgrammersRetrieval.py',
#  'CQADupstackStatsRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackStatsRetrieval.py',
#  'CQADupstackTexRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackTexRetrieval.py',
#  'CQADupstackUnixRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackUnixRetrieval.py',
#  'CQADupstackWebmastersRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackWebmastersRetrieval.py',
#  'CQADupstackWordpressRetrieval': 'mteb/tasks/Retrieval/eng/CQADupstackWordpressRetrieval.py',
#  'DBPediaRetrieval': 'mteb/tasks/Retrieval/eng/DBPediaRetrieval.py',
#  'FEVERRetrieval': 'mteb/tasks/Retrieval/eng/FEVERRetrieval.py',
#  'FiQA2018Retrieval': 'mteb/tasks/Retrieval/eng/FiQA2018Retrieval.py',
#  'HagridRetrieval': 'mteb/tasks/Retrieval/eng/HagridRetrieval.py',
#  'HotpotQARetrieval': 'mteb/tasks/Retrieval/eng/HotpotQARetrieval.py',
#  'LegalBenchConsumerContractsQARetrieval': 'mteb/tasks/Retrieval/eng/LegalBenchConsumerContractsQARetrieval.py',
#  'LegalBenchCorporateLobbyingRetrieval': 'mteb/tasks/Retrieval/eng/LegalBenchCorporateLobbyingRetrieval.py',
#  'LegalSummarizationRetrieval': 'mteb/tasks/Retrieval/eng/LegalSummarizationRetrieval.py',
#  'LEMBNarrativeQARetrieval': 'mteb/tasks/Retrieval/eng/LEMBNarrativeQARetrieval.py',
#  'LEMBNeedleRetrieval': 'mteb/tasks/Retrieval/eng/LEMBNeedleRetrieval.py',
#  'LEMBPasskeyRetrieval': 'mteb/tasks/Retrieval/eng/LEMBPasskeyRetrieval.py',
#  'LEMBQMSumRetrieval': 'mteb/tasks/Retrieval/eng/LEMBQMSumRetrieval.py',
#  'LEMBSummScreenFDRetrieval': 'mteb/tasks/Retrieval/eng/LEMBSummScreenFDRetrieval.py',
#  'LEMBWikimQARetrieval': 'mteb/tasks/Retrieval/eng/LEMBWikimQARetrieval.py',
#  'MedicalQARetrieval': 'mteb/tasks/Retrieval/eng/MedicalQARetrieval.py',
#  'MSMARCORetrieval': 'mteb/tasks/Retrieval/eng/MSMARCORetrieval.py',
#  'MSMARCOv2Retrieval': 'mteb/tasks/Retrieval/eng/MSMARCOv2Retrieval.py',
#  'NarrativeQARetrieval': 'mteb/tasks/Retrieval/eng/NarrativeQARetrieval.py',
#  'NFCorpusRetrieval': 'mteb/tasks/Retrieval/eng/NFCorpusRetrieval.py',
#  'NQRetrieval': 'mteb/tasks/Retrieval/eng/NQRetrieval.py',
#  'QuoraRetrieval': 'mteb/tasks/Retrieval/eng/QuoraRetrieval.py',
#  'SCIDOCSRetrieval': 'mteb/tasks/Retrieval/eng/SCIDOCSRetrieval.py',
#  'SciFactRetrieval': 'mteb/tasks/Retrieval/eng/SciFactRetrieval.py',
#  'Touche2020Retrieval': 'mteb/tasks/Retrieval/eng/Touche2020Retrieval.py',
#  'TRECCOVIDRetrieval': 'mteb/tasks/Retrieval/eng/TRECCOVIDRetrieval.py',
#  'estqa': 'mteb/tasks/Retrieval/est/estqa.py',
#  'AlloprofRetrieval': 'mteb/tasks/Retrieval/fra/AlloprofRetrieval.py',
#  'BSARDRetrieval': 'mteb/tasks/Retrieval/fra/BSARDRetrieval.py',
#  'FQuADRetrieval': 'mteb/tasks/Retrieval/fra/FQuADRetrieval.py',
#  'SyntecRetrieval': 'mteb/tasks/Retrieval/fra/SyntecRetrieval.py',
#  'HunSum2': 'mteb/tasks/Retrieval/hun/HunSum2.py',
#  'JaQuADRetrieval': 'mteb/tasks/Retrieval/jpn/JaQuADRetrieval.py',
#  'KoMiracl': 'mteb/tasks/Retrieval/kor/KoMiracl.py',
#  'KoStrategyQA': 'mteb/tasks/Retrieval/kor/KoStrategyQA.py',
#  'IndicQARetrieval': 'mteb/tasks/Retrieval/multilingual/IndicQARetrieval.py',
#  'MintakaRetrieval': 'mteb/tasks/Retrieval/multilingual/MintakaRetrieval.py',
#  'MIRACLRetrieval': 'mteb/tasks/Retrieval/multilingual/MIRACLRetrieval.py',
#  'MultiLongDocRetrieval': 'mteb/tasks/Retrieval/multilingual/MultiLongDocRetrieval.py',
#  'NeuCLIR2022Retrieval': 'mteb/tasks/Retrieval/multilingual/NeuCLIR2022Retrieval.py',
#  'NeuCLIR2023Retrieval': 'mteb/tasks/Retrieval/multilingual/NeuCLIR2023Retrieval.py',
#  'XMarketRetrieval': 'mteb/tasks/Retrieval/multilingual/XMarketRetrieval.py',
#  'XPQARetrieval': 'mteb/tasks/Retrieval/multilingual/XPQARetrieval.py',
#  'XQuADRetrieval': 'mteb/tasks/Retrieval/multilingual/XQuADRetrieval.py',
#  'norquad': 'mteb/tasks/Retrieval/nob/norquad.py',
#  'snl_retrieval': 'mteb/tasks/Retrieval/nob/snl_retrieval.py',
#  'ArguAnaPLRetrieval': 'mteb/tasks/Retrieval/pol/ArguAnaPLRetrieval.py',
#  'DBPediaPLRetrieval': 'mteb/tasks/Retrieval/pol/DBPediaPLRetrieval.py',
#  'FiQAPLRetrieval': 'mteb/tasks/Retrieval/pol/FiQAPLRetrieval.py',
#  'HotpotQAPLRetrieval': 'mteb/tasks/Retrieval/pol/HotpotQAPLRetrieval.py',
#  'MSMARCOPLRetrieval': 'mteb/tasks/Retrieval/pol/MSMARCOPLRetrieval.py',
#  'NFCorpusPLRetrieval': 'mteb/tasks/Retrieval/pol/NFCorpusPLRetrieval.py',
#  'NQPLRetrieval': 'mteb/tasks/Retrieval/pol/NQPLRetrieval.py',
#  'QuoraPLRetrieval': 'mteb/tasks/Retrieval/pol/QuoraPLRetrieval.py',
#  'SCIDOCSPLRetrieval': 'mteb/tasks/Retrieval/pol/SCIDOCSPLRetrieval.py',
#  'SciFactPLRetrieval': 'mteb/tasks/Retrieval/pol/SciFactPLRetrieval.py',
#  'TRECCOVIDPLRetrieval': 'mteb/tasks/Retrieval/pol/TRECCOVIDPLRetrieval.py',
#  'SlovakSumRetrieval': 'mteb/tasks/Retrieval/slk/SlovakSumRetrieval.py',
#  'SpanishPassageRetrievalS2P': 'mteb/tasks/Retrieval/spa/SpanishPassageRetrievalS2P.py',
#  'SpanishPassageRetrievalS2S': 'mteb/tasks/Retrieval/spa/SpanishPassageRetrievalS2S.py',
#  'swedn_retrieval': 'mteb/tasks/Retrieval/swe/swedn_retrieval.py',
#  'swefaq_retrieval': 'mteb/tasks/Retrieval/swe/swefaq_retrieval.py',
#  'TurHistQuad': 'mteb/tasks/Retrieval/tur/TurHistQuad.py',
#  'VieQuADRetrieval': 'mteb/tasks/Retrieval/vie/VieQuADRetrieval.py',
#  'CMTEBRetrieval': 'mteb/tasks/Retrieval/zho/CMTEBRetrieval.py',
#  'LeCaRDv2Retrieval': 'mteb/tasks/Retrieval/zho/LeCaRDv2Retrieval.py',
#  'GermanSTSBenchmarkSTS': 'mteb/tasks/STS/deu/GermanSTSBenchmarkSTS.py',
#  'BiossesSTS': 'mteb/tasks/STS/eng/BiossesSTS.py',
#  'SickrSTS': 'mteb/tasks/STS/eng/SickrSTS.py',
#  'STS12STS': 'mteb/tasks/STS/eng/STS12STS.py',
#  'STS13STS': 'mteb/tasks/STS/eng/STS13STS.py',
#  'STS14STS': 'mteb/tasks/STS/eng/STS14STS.py',
#  'STS15STS': 'mteb/tasks/STS/eng/STS15STS.py',
#  'STS16STS': 'mteb/tasks/STS/eng/STS16STS.py',
#  'STSBenchmarkSTS': 'mteb/tasks/STS/eng/STSBenchmarkSTS.py',
#  'FinParaSTS': 'mteb/tasks/STS/fin/FinParaSTS.py',
#  'SickFrSTS': 'mteb/tasks/STS/fra/SickFrSTS.py',
#  'JSTS': 'mteb/tasks/STS/jpn/JSTS.py',
#  'KlueSTS': 'mteb/tasks/STS/kor/KlueSTS.py',
#  'KorSTS': 'mteb/tasks/STS/kor/KorSTS.py',
#  'IndicCrosslingualSTS': 'mteb/tasks/STS/multilingual/IndicCrosslingualSTS.py',
#  'STS17CrosslingualSTS': 'mteb/tasks/STS/multilingual/STS17CrosslingualSTS.py',
#  'STS22CrosslingualSTS': 'mteb/tasks/STS/multilingual/STS22CrosslingualSTS.py',
#  'STSBenchmarkMultilingualSTS': 'mteb/tasks/STS/multilingual/STSBenchmarkMultilingualSTS.py',
#  'PolishSTS': 'mteb/tasks/STS/pol/PolishSTS.py',
#  'RonSTS': 'mteb/tasks/STS/ron/RonSTS.py',
#  'STSES': 'mteb/tasks/STS/spa/STSES.py',
#  'CMTEBSTS': 'mteb/tasks/STS/zho/CMTEBSTS.py',
#  'SummEvalSummarization': 'mteb/tasks/Summarization/eng/SummEvalSummarization.py',
#  'SummEvalFrSummarization': 'mteb/tasks/Summarization/fra/SummEvalFrSummarization.py'}

# %%
import huggingface_hub
from tqdm.auto import tqdm
import os

size_data = {}

for dataset_info in tqdm(huggingface_hub.list_datasets(author="mteb-pt", full=False)):
    huggingface_hub.move_repo(dataset_info.id, f'mteb-pt/translated_{os.path.basename(dataset_info.id)}', repo_type='dataset')
# Out:
# 0it [00:00, ?it/s]

# %%
from datasets import load_dataset
#dataset = load_dataset("eduagarcia/PortuLex_benchmark", name='rrip')
dataset.push_to_hub('eduagarcia/portuguese_benchmark', config_name='rrip')
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/17.5k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/eduagarcia/portuguese_benchmark/commit/f28ff5f68ad7930e909ee82c212bcdc5427ccd91', commit_message='Upload dataset', commit_description='', oid='f28ff5f68ad7930e909ee82c212bcdc5427ccd91', pr_url=None, pr_revision=None, pr_num=None)

# %%
from portuguese_benchmark_disabled import PTBenchmark

# %%
citations = {}

for name, config in PTBenchmark.builder_configs.items():
    if config.citation not in citations:
        citations[config.citation] = [name]
    else:
        citations[config.citation].append(name)

for c in citations:
    print(f"# {', '.join(citations[c])}")
    print(c)
    print()
# Out:
# # LeNER-Br
# @InProceedings{luz_etal_propor2018,
#     author = {Pedro H. {Luz de Araujo} and Te'{o}filo E. {de Campos} and
#             Renato R. R. {de Oliveira} and Matheus Stauffer and
#             Samuel Couto and Paulo Bermejo},
#     title = {{LeNER-Br}: a Dataset for Named Entity Recognition in {Brazilian} Legal Text},
#     booktitle = {International Conference on the Computational Processing of Portuguese ({PROPOR})},
#     publisher = {Springer},
#     series = {Lecture Notes on Computer Science ({LNCS})},
#     pages = {313--323},
#     year = {2018},
#     month = {September 24-26},
#     address = {Canela, RS, Brazil},
#     doi = {10.1007/978-3-319-99722-3_32},
#     url = {https://teodecampos.github.io/LeNER-Br/},
# }
#
# # assin2-rte, assin2-sts
# @inproceedings{real2020assin,
#     title={The assin 2 shared task: a quick overview},
#     author={Real, Livy and Fonseca, Erick and Oliveira, Hugo Goncalo},
#     booktitle={International Conference on Computational Processing of the Portuguese Language},
#     pages={406--412},
#     year={2020},
#     organization={Springer}
# }
#
# # HateBR_offensive_binary, HateBR_offensive_level
# @inproceedings{vargas2022hatebr,
#     title={HateBR: A Large Expert Annotated Corpus of Brazilian Instagram Comments for Offensive Language and Hate Speech Detection},
#     author={Vargas, Francielle and Carvalho, Isabelle and de G{'o}es, Fabiana Rodrigues and Pardo, Thiago and Benevenuto, Fabr{'\i}cio},
#     booktitle={Proceedings of the Thirteenth Language Resources and Evaluation Conference},
#     pages={7174--7183},
#     year={2022}
# }
#
# # UlyssesNER-Br-PL-coarse, UlyssesNER-Br-C-coarse, UlyssesNER-Br-PL-fine, UlyssesNER-Br-C-fine
# @InProceedings{10.1007/978-3-030-98305-5_1,
#     author="Albuquerque, Hidelberg O.
#     and Costa, Rosimeire
#     and Silvestre, Gabriel
#     and Souza, Ellen
#     and da Silva, N{'a}dia F. F.
#     and Vit{'o}rio, Douglas
#     and Moriyama, Gyovana
#     and Martins, Lucas
#     and Soezima, Luiza
#     and Nunes, Augusto
#     and Siqueira, Felipe
#     and Tarrega, Jo{\~a}o P.
#     and Beinotti, Joao V.
#     and Dias, Marcio
#     and Silva, Matheus
#     and Gardini, Miguel
#     and Silva, Vinicius
#     and de Carvalho, Andr{'e} C. P. L. F.
#     and Oliveira, Adriano L. I.",
#     editor="Pinheiro, Vl{'a}dia
#     and Gamallo, Pablo
#     and Amaro, Raquel
#     and Scarton, Carolina
#     and Batista, Fernando
#     and Silva, Diego
#     and Magro, Catarina
#     and Pinto, Hugo",
#     title="UlyssesNER-Br: A Corpus of Brazilian Legislative Documents for Named Entity Recognition",
#     booktitle="Computational Processing of the Portuguese Language",
#     year="2022",
#     publisher="Springer International Publishing",
#     address="Cham",
#     pages="3--14",
#     isbn="978-3-030-98305-5"
# }
# @InProceedings{10.1007/978-3-031-16474-3_62,
#     author="Costa, Rosimeire
#     and Albuquerque, Hidelberg Oliveira
#     and Silvestre, Gabriel
#     and Silva, N{'a}dia F{'e}lix F.
#     and Souza, Ellen
#     and Vit{'o}rio, Douglas
#     and Nunes, Augusto
#     and Siqueira, Felipe
#     and Pedro Tarrega, Jo{\~a}o
#     and Vitor Beinotti, Jo{\~a}o
#     and de Souza Dias, M{'a}rcio
#     and Pereira, Fab{'i}ola S. F.
#     and Silva, Matheus
#     and Gardini, Miguel
#     and Silva, Vinicius
#     and de Carvalho, Andr{'e} C. P. L. F.
#     and Oliveira, Adriano L. I.",
#     editor="Marreiros, Goreti
#     and Martins, Bruno
#     and Paiva, Ana
#     and Ribeiro, Bernardete
#     and Sardinha, Alberto",
#     title="Expanding UlyssesNER-Br Named Entity Recognition Corpus with Informal User-Generated Text",
#     booktitle="Progress in Artificial Intelligence",
#     year="2022",
#     publisher="Springer International Publishing",
#     address="Cham",
#     pages="767--779",
#     isbn="978-3-031-16474-3"
# }
#
# # brazilian_court_decisions_judgment, brazilian_court_decisions_unanimity
# @article{Lage-Freitas2022,
#   author = {Lage-Freitas, Andr{'{e}} and Allende-Cid, H{'{e}}ctor and Santana, Orivaldo and Oliveira-Lage, L{'{i}}via},
#   doi = {10.7717/peerj-cs.904},
#   issn = {2376-5992},
#   journal = {PeerJ. Computer science},
#   keywords = {Artificial intelligence,Jurimetrics,Law,Legal,Legal NLP,Legal informatics,Legal outcome forecast,Litigation prediction,Machine learning,NLP,Portuguese,Predictive algorithms,judgement prediction},
#   language = {eng},
#   month = {mar},
#   pages = {e904--e904},
#   publisher = {PeerJ Inc.},
#   title = {{Predicting Brazilian Court Decisions}},
#   url = {https://pubmed.ncbi.nlm.nih.gov/35494851 https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9044329/},
#   volume = {8},
#   year = {2022}
# }
#
# # harem-default, harem-selective
# @inproceedings{santos2006harem,
#     title={Harem: An advanced ner evaluation contest for portuguese},
#     author={Santos, Diana and Seco, Nuno and Cardoso, Nuno and Vilela, Rui},
#     booktitle={quot; In Nicoletta Calzolari; Khalid Choukri; Aldo Gangemi; Bente Maegaard; Joseph Mariani; Jan Odjik; Daniel Tapias (ed) Proceedings of the 5 th International Conference on Language Resources and Evaluation (LREC'2006)(Genoa Italy 22-28 May 2006)},
#     year={2006}
# }
#
# # multi_eurlex_pt
# @InProceedings{chalkidis-etal-2021-multieurlex,
#   author = {Chalkidis, Ilias
#                 and Fergadiotis, Manos
#                 and Androutsopoulos, Ion},
#   title = {MultiEURLEX -- A multi-lingual and multi-label legal document
#                classification dataset for zero-shot cross-lingual transfer},
#   booktitle = {Proceedings of the 2021 Conference on Empirical Methods
#                in Natural Language Processing},
#   year = {2021},
#   publisher = {Association for Computational Linguistics},
#   location = {Punta Cana, Dominican Republic},
#   url = {https://arxiv.org/abs/2109.00904}
# }
#
# # mapa_pt_coarse, mapa_pt_fine
# @article{DeGibertBonet2022,
#     author = {{de Gibert Bonet}, Ona and {Garc{'{i}}a Pablos}, Aitor and Cuadros, Montse and Melero, Maite},
#     journal = {Proceedings of the Language Resources and Evaluation Conference},
#     number = {June},
#     pages = {3751--3760},
#     title = {{Spanish Datasets for Sensitive Entity Detection in the Legal Domain}},
#     url = {https://aclanthology.org/2022.lrec-1.400},
#     year = {2022}
# }
#
# # Portuguese_Hate_Speech_binary
# @inproceedings{fortuna-etal-2019-hierarchically,
#     title = "A Hierarchically-Labeled {P}ortuguese Hate Speech Dataset",
#     author = "Fortuna, Paula  and
#     Rocha da Silva, Jo{\~a}o  and
#     Soler-Company, Juan  and
#     Wanner, Leo  and
#     Nunes, S{'e}rgio",
#     editor = "Roberts, Sarah T.  and
#     Tetreault, Joel  and
#     Prabhakaran, Vinodkumar  and
#     Waseem, Zeerak",
#     booktitle = "Proceedings of the Third Workshop on Abusive Language Online",
#     month = aug,
#     year = "2019",
#     address = "Florence, Italy",
#     publisher = "Association for Computational Linguistics",
#     url = "https://aclanthology.org/W19-3510",
#     doi = "10.18653/v1/W19-3510",
#     pages = "94--104"
# }

# %%
#Table markdown tasks
tasks_types = {}
task_name_map = {
    'ner': 'NER',
    'classification': 'Classification',
    'sts': 'STS',
    'rte': 'NLI',
    'multilabel_classification': 'Classification'
}
for name, config in PTBenchmark.builder_configs.items():
    task_type = task_name_map[config.task_type]
    name_str = f"[{name}]({config.url})"
    #if config.url is None or config.url == '':
    #    name_str = name
    if task_type not in tasks_types:
        tasks_types[task_type] = [name_str]
    else:
        tasks_types[task_type].append(name_str)

print('| NER | Classification | NLI | STS |')
print('|---|---|---|---|')
max_len = max([len(tasks_types[t]) for t in tasks_types])
for i in range(max_len):
    row = []
    for task_type in ["NER", "Classification", "NLI", "STS"]:
        if i < len(tasks_types[task_type]):
            row.append(tasks_types[task_type][i])
        else:
            row.append('')
    print('| ' + ' | '.join(row) + ' |')
# Out:
# | NER | Classification | NLI | STS |
# |---|---|---|---|
# | [LeNER-Br](https://teodecampos.github.io/LeNER-Br/) | [HateBR_offensive_binary](https://github.com/franciellevargas/HateBR) | [assin2-rte](https://sites.google.com/view/assin2) | [assin2-sts](https://sites.google.com/view/assin2) |
# | [UlyssesNER-Br-PL-coarse](https://github.com/ulysses-camara/ulysses-ner-br) | [HateBR_offensive_level](https://github.com/franciellevargas/HateBR) |  |  |
# | [UlyssesNER-Br-C-coarse](https://github.com/ulysses-camara/ulysses-ner-br) | [brazilian_court_decisions_judgment](https://github.com/lagefreitas/predicting-brazilian-court-decisions) |  |  |
# | [UlyssesNER-Br-PL-fine](https://github.com/ulysses-camara/ulysses-ner-br) | [brazilian_court_decisions_unanimity](https://github.com/lagefreitas/predicting-brazilian-court-decisions) |  |  |
# | [UlyssesNER-Br-C-fine](https://github.com/ulysses-camara/ulysses-ner-br) | [multi_eurlex_pt](https://github.com/nlpaueb/MultiEURLEX/) |  |  |
# | [harem-default](https://www.linguateca.pt/primeiroHAREM/harem_coleccaodourada_en.html) | [Portuguese_Hate_Speech_binary](https://github.com/paulafortuna/Portuguese-Hate-Speech-Dataset) |  |  |
# | [harem-selective](https://www.linguateca.pt/primeiroHAREM/harem_coleccaodourada_en.html) |  |  |  |
# | [mapa_pt_coarse]() |  |  |  |
# | [mapa_pt_fine]() |  |  |  |

# %%
tasks_types
# Out:
# {'ner': ['LeNER-Br',
#   'UlyssesNER-Br-PL-coarse',
#   'UlyssesNER-Br-C-coarse',
#   'UlyssesNER-Br-PL-fine',
#   'UlyssesNER-Br-C-fine',
#   'harem-default',
#   'harem-selective',
#   'mapa_pt_coarse',
#   'mapa_pt_fine'],
#  'rte': ['assin2-rte'],
#  'sts': ['assin2-sts'],
#  'classification': ['HateBR_offensive_binary',
#   'HateBR_offensive_level',
#   'brazilian_court_decisions_judgment',
#   'brazilian_court_decisions_unanimity',
#   'Portuguese_Hate_Speech_binary'],
#  'multilabel_classification': ['multi_eurlex_pt']}

# %%
for name, config in PTBenchmark.builder_configs.items():
    print(f"**{name}** ({config.task_type.replace('_', ' ').upper()}) [\[Link\]]({config.url})")
    print()
    print(config.description)
    print()
# Out:
# **LeNER-Br** (NER) [\[Link\]](https://teodecampos.github.io/LeNER-Br/)
#
# LeNER-Br is a Portuguese language dataset for named entity recognition applied to legal documents.
# LeNER-Br consists entirely of manually annotated legislation and legal cases texts and contains tags
# for persons, locations, time entities, organizations, legislation and legal cases. To compose the dataset,
# 66 legal documents from several Brazilian Courts were collected. Courts of superior and state levels were considered,
# such as Supremo Tribunal Federal, Superior Tribunal de Justiça, Tribunal de Justiça de Minas Gerais and Tribunal de Contas da União.
# In addition, four legislation documents were collected, such as "Lei Maria da Penha", giving a total of 70 documents.
#
# **assin2-rte** (RTE) [\[Link\]](https://sites.google.com/view/assin2)
#
# The ASSIN 2 corpus is composed of rather simple sentences. Following the procedures of SemEval 2014 Task 1.
# The training and validation data are composed, respectively, of 6,500 and 500 sentence pairs in Brazilian Portuguese,
# annotated for entailment and semantic similarity. Semantic similarity values range from 1 to 5, and text entailment
# classes are either entailment or none. The test data are composed of approximately 3,000 sentence pairs with the same
# annotation. All data were manually annotated.
#
# **assin2-sts** (STS) [\[Link\]](https://sites.google.com/view/assin2)
#
# The ASSIN 2 corpus is composed of rather simple sentences. Following the procedures of SemEval 2014 Task 1.
# The training and validation data are composed, respectively, of 6,500 and 500 sentence pairs in Brazilian Portuguese,
# annotated for entailment and semantic similarity. Semantic similarity values range from 1 to 5, and text entailment
# classes are either entailment or none. The test data are composed of approximately 3,000 sentence pairs with the same
# annotation. All data were manually annotated.
#
# **HateBR_offensive_binary** (CLASSIFICATION) [\[Link\]](https://github.com/franciellevargas/HateBR)
#
# HateBR is the first large-scale expert annotated dataset of Brazilian Instagram comments for abusive language detection
# on the web and social media. The HateBR was collected from Brazilian Instagram comments of politicians and manually annotated
# by specialists. It is composed of 7,000 documents annotated according to three different layers: a binary classification (offensive
# versus non-offensive comments), offensiveness-level (highly, moderately, and slightly offensive messages), and nine hate speech
# groups (xenophobia, racism, homophobia, sexism, religious intolerance, partyism, apology for the dictatorship, antisemitism,
# and fatphobia). Each comment was annotated by three different annotators and achieved high inter-annotator agreement. Furthermore,
# baseline experiments were implemented reaching 85% of F1-score outperforming the current literature dataset baselines for
# the Portuguese language. We hope that the proposed expert annotated dataset may foster research on hate speech detection in the
# Natural Language Processing area.
#
# **HateBR_offensive_level** (CLASSIFICATION) [\[Link\]](https://github.com/franciellevargas/HateBR)
#
# HateBR is the first large-scale expert annotated dataset of Brazilian Instagram comments for abusive language detection
# on the web and social media. The HateBR was collected from Brazilian Instagram comments of politicians and manually annotated
# by specialists. It is composed of 7,000 documents annotated according to three different layers: a binary classification (offensive
# versus non-offensive comments), offensiveness-level (highly, moderately, and slightly offensive messages), and nine hate speech
# groups (xenophobia, racism, homophobia, sexism, religious intolerance, partyism, apology for the dictatorship, antisemitism,
# and fatphobia). Each comment was annotated by three different annotators and achieved high inter-annotator agreement. Furthermore,
# baseline experiments were implemented reaching 85% of F1-score outperforming the current literature dataset baselines for
# the Portuguese language. We hope that the proposed expert annotated dataset may foster research on hate speech detection in the
# Natural Language Processing area.
#
# **UlyssesNER-Br-PL-coarse** (NER) [\[Link\]](https://github.com/ulysses-camara/ulysses-ner-br)
#
# UlyssesNER-Br is a corpus of Brazilian Legislative Documents for NER with quality baselines.
# The presented corpus consists of bills and legislative consultations from Brazilian Chamber of Deputies.
# UlyssesNER-Br has seven semantic classes or categories. Based on HAREM,
# we defined five typical categories: person, location, organization, event and date.
# In addition, we defined two specific semantic classes for the legislative domain:
# law foundation and law product. The law foundation category makes reference to
# entities related to laws, resolutions, decrees, as well as to domain-specific entities
# such as bills, which are law proposals being discussed by the parliament, and legislative consultations,
# also known as job requests made by the parliamentarians.
# The law product entity refers to systems, programs, and other products created
# from legislation.
#
# **UlyssesNER-Br-C-coarse** (NER) [\[Link\]](https://github.com/ulysses-camara/ulysses-ner-br)
#
# UlyssesNER-Br is a corpus of Brazilian Legislative Documents for NER with quality baselines.
# The presented corpus consists of bills and legislative consultations from Brazilian Chamber of Deputies.
# UlyssesNER-Br has seven semantic classes or categories. Based on HAREM,
# we defined five typical categories: person, location, organization, event and date.
# In addition, we defined two specific semantic classes for the legislative domain:
# law foundation and law product. The law foundation category makes reference to
# entities related to laws, resolutions, decrees, as well as to domain-specific entities
# such as bills, which are law proposals being discussed by the parliament, and legislative consultations,
# also known as job requests made by the parliamentarians.
# The law product entity refers to systems, programs, and other products created
# from legislation.
#
# **UlyssesNER-Br-PL-fine** (NER) [\[Link\]](https://github.com/ulysses-camara/ulysses-ner-br)
#
# UlyssesNER-Br is a corpus of Brazilian Legislative Documents for NER with quality baselines.
# The presented corpus consists of bills and legislative consultations from Brazilian Chamber of Deputies.
# UlyssesNER-Br has seven semantic classes or categories. Based on HAREM,
# we defined five typical categories: person, location, organization, event and date.
# In addition, we defined two specific semantic classes for the legislative domain:
# law foundation and law product. The law foundation category makes reference to
# entities related to laws, resolutions, decrees, as well as to domain-specific entities
# such as bills, which are law proposals being discussed by the parliament, and legislative consultations,
# also known as job requests made by the parliamentarians.
# The law product entity refers to systems, programs, and other products created
# from legislation.
#
# **UlyssesNER-Br-C-fine** (NER) [\[Link\]](https://github.com/ulysses-camara/ulysses-ner-br)
#
# UlyssesNER-Br is a corpus of Brazilian Legislative Documents for NER with quality baselines.
# The presented corpus consists of bills and legislative consultations from Brazilian Chamber of Deputies.
# UlyssesNER-Br has seven semantic classes or categories. Based on HAREM,
# we defined five typical categories: person, location, organization, event and date.
# In addition, we defined two specific semantic classes for the legislative domain:
# law foundation and law product. The law foundation category makes reference to
# entities related to laws, resolutions, decrees, as well as to domain-specific entities
# such as bills, which are law proposals being discussed by the parliament, and legislative consultations,
# also known as job requests made by the parliamentarians.
# The law product entity refers to systems, programs, and other products created
# from legislation.
#
# **brazilian_court_decisions_judgment** (CLASSIFICATION) [\[Link\]](https://github.com/lagefreitas/predicting-brazilian-court-decisions)
#
# The dataset is a collection of 4043 Ementa (summary) court decisions and their metadata from the Tribunal de
# Justiça de Alagoas (TJAL, the State Supreme Court of Alagoas (Brazil). The court decisions are labeled according
# to 7 categories and whether the decisions were unanimous on the part of the judges or not. The dataset
# supports the task of Legal Judgment Prediction.
#
# **brazilian_court_decisions_unanimity** (CLASSIFICATION) [\[Link\]](https://github.com/lagefreitas/predicting-brazilian-court-decisions)
#
# The dataset is a collection of 4043 Ementa (summary) court decisions and their metadata from the Tribunal de
# Justiça de Alagoas (TJAL, the State Supreme Court of Alagoas (Brazil). The court decisions are labeled according
# to 7 categories and whether the decisions were unanimous on the part of the judges or not. The dataset
# supports the task of Legal Judgment Prediction.
#
# **harem-default** (NER) [\[Link\]](https://www.linguateca.pt/primeiroHAREM/harem_coleccaodourada_en.html)
#
# The HAREM is a Portuguese language corpus commonly used for Named Entity Recognition tasks. It includes about 93k words, from 129 different texts,
# from several genres, and language varieties. The split of this dataset version follows the division made by [1], where 7% HAREM
# documents are the validation set and the miniHAREM corpus (with about 65k words) is the test set. There are two versions of the dataset set,
# a version that has a total of 10 different named entity classes (Person, Organization, Location, Value, Date, Title, Thing, Event,
# Abstraction, and Other) and a "selective" version with only 5 classes (Person, Organization, Location, Value, and Date).
# It's important to note that the original version of the HAREM dataset has 2 levels of NER details, namely "Category" and "Sub-type".
# The dataset version processed here ONLY USE the "Category" level of the original dataset.
# [1] Souza, Fábio, Rodrigo Nogueira, and Roberto Lotufo. "BERTimbau: Pretrained BERT Models for Brazilian Portuguese."
# Brazilian Conference on Intelligent Systems. Springer, Cham, 2020.
#
# **harem-selective** (NER) [\[Link\]](https://www.linguateca.pt/primeiroHAREM/harem_coleccaodourada_en.html)
#
# The HAREM is a Portuguese language corpus commonly used for Named Entity Recognition tasks. It includes about 93k words, from 129 different texts,
# from several genres, and language varieties. The split of this dataset version follows the division made by [1], where 7% HAREM
# documents are the validation set and the miniHAREM corpus (with about 65k words) is the test set. There are two versions of the dataset set,
# a version that has a total of 10 different named entity classes (Person, Organization, Location, Value, Date, Title, Thing, Event,
# Abstraction, and Other) and a "selective" version with only 5 classes (Person, Organization, Location, Value, and Date).
# It's important to note that the original version of the HAREM dataset has 2 levels of NER details, namely "Category" and "Sub-type".
# The dataset version processed here ONLY USE the "Category" level of the original dataset.
# [1] Souza, Fábio, Rodrigo Nogueira, and Roberto Lotufo. "BERTimbau: Pretrained BERT Models for Brazilian Portuguese."
# Brazilian Conference on Intelligent Systems. Springer, Cham, 2020.
#
# **multi_eurlex_pt** (MULTILABEL CLASSIFICATION) [\[Link\]](https://github.com/nlpaueb/MultiEURLEX/)
#
# MultiEURLEX comprises 65k EU laws in 23 official EU languages.
# Each EU law has been annotated with EUROVOC concepts (labels) by the Publication Office of EU.
# Each EUROVOC label ID is associated with a label descriptor, e.g., [60, agri-foodstuffs],
# [6006, plant product], [1115, fruit]. The descriptors are also available in the 23 languages.
# Chalkidis et al. (2019) published a monolingual (English) version of this dataset, called EUR-LEX,
# comprising 57k EU laws with the originally assigned gold labels.
#
# **mapa_pt_coarse** (NER) [\[Link\]]()
#
# The dataset consists of 12 documents (9 for Spanish due to parsing errors) taken from EUR-Lex,
# a multilingual corpus of court decisions and legal dispositions in the 24 official languages
# of the European Union. The documents have been annotated for named entities following the
# guidelines of the MAPA project which foresees two annotation level, a general and a more
# fine-grained one. The annotated corpus can be used for named entity recognition/classification.
#
# **mapa_pt_fine** (NER) [\[Link\]]()
#
# The dataset consists of 12 documents (9 for Spanish due to parsing errors) taken from EUR-Lex,
# a multilingual corpus of court decisions and legal dispositions in the 24 official languages
# of the European Union. The documents have been annotated for named entities following the
# guidelines of the MAPA project which foresees two annotation level, a general and a more
# fine-grained one. The annotated corpus can be used for named entity recognition/classification.
#
# **Portuguese_Hate_Speech_binary** (CLASSIFICATION) [\[Link\]](https://github.com/paulafortuna/Portuguese-Hate-Speech-Dataset)
#
# The dataset is composed of 5,668 tweets. For its annotation, we defined two different schemes used by
# annotators with different levels of expertise. Firstly, non-experts annotated the tweets with binary
# labels (‘hate’ vs. ‘no-hate’). Secondly, expert annotators classified the tweets following a fine-grained
# hierarchical multiple label scheme with 81 hate speech categories in total. The inter-annotator agreement
# varied from category to category, which reflects the insight that some types of hate speech are more subtle
# than others and that their detection depends on personal perception. This hierarchical annotation scheme is
# the main contribution of the presented work, as it facilitates the identification of different types of
# hate speech and their intersections.

# %%
analysis_dataset = "mteb-pt/pira2_retrieval"
config_name="corpus"
text_columns = ["text"]

n_samples={}
avg_character_length={}

from datasets import load_dataset
dataset = load_dataset(analysis_dataset, name=config_name)

for split in dataset.keys():
    n_samples[split] = len(dataset[split])
    caracter_lengths = []
    for d in range(len(dataset[split])):
        for col in text_columns:
            texts = dataset[split][d][col]
            if isinstance(texts, str):
                texts = [texts]
            for text in texts:
                caracter_lengths.append(len(text))
    avg_character_length[split] = round(sum(caracter_lengths)/len(caracter_lengths),1)

print(f"n_samples={n_samples},")
print(f"avg_character_length={avg_character_length}")
# Out:
# Downloading data:   0%|          | 0.00/718k [00:00<?, ?B/s]
# Generating corpus split:   0%|          | 0/702 [00:00<?, ? examples/s]
# n_samples={'corpus': 702},
# avg_character_length={'corpus': 1745.8}
